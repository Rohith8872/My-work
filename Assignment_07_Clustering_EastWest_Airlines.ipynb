# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import normalize
from sklearn.cluster import KMeans
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_excel('EastWestAirlines.xlsx', sheet_name='data')
data.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %% [markdown]
# # EDA

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
data.describe()
# Out:
#                ID#       Balance    Qual_miles    cc1_miles    cc2_miles  \
# count  3999.000000  3.999000e+03   3999.000000  3999.000000  3999.000000
# mean   2014.819455  7.360133e+04    144.114529     2.059515     1.014504
# std    1160.764358  1.007757e+05    773.663804     1.376919     0.147650
# min       1.000000  0.000000e+00      0.000000     1.000000     1.000000
# 25%    1010.500000  1.852750e+04      0.000000     1.000000     1.000000
# 50%    2016.000000  4.309700e+04      0.000000     1.000000     1.000000
# 75%    3020.500000  9.240400e+04      0.000000     3.000000     1.000000
# max    4021.000000  1.704838e+06  11148.000000     5.000000     3.000000
#
#          cc3_miles    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# count  3999.000000    3999.000000   3999.00000        3999.000000
# mean      1.012253   17144.846212     11.60190         460.055764
# std       0.195241   24150.967826      9.60381        1400.209171
# ...

# %%
data1 = data.drop('ID#', axis=1)
data1.head()
# Out:
#    Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    28143           0          1          1          1          174
# 1    19244           0          1          1          1          215
# 2    41354           0          1          1          1         4123
# 3    14776           0          1          1          1          500
# 4    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
data2 = data1.copy()
data2
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
norm_data=pd.DataFrame(normalize(data2),columns=data2.columns)
norm_data
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.970414         0.0   0.000034   0.000034   0.000034     0.006000
# 1     0.940209         0.0   0.000049   0.000049   0.000049     0.010504
# 2     0.981113         0.0   0.000024   0.000024   0.000024     0.097817
# 3     0.904428         0.0   0.000061   0.000061   0.000061     0.030605
# 4     0.912226         0.0   0.000037   0.000009   0.000009     0.404078
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.905810         0.0   0.000049   0.000049   0.000049     0.417949
# 3995  0.999649         0.0   0.000016   0.000016   0.000016     0.015231
# 3996  0.944948         0.0   0.000039   0.000013   0.000013     0.326726
# 3997  0.999592         0.0   0.000018   0.000018   0.000018     0.009104
# 3998  0.907271         0.0   0.000301   0.000301   0.000301     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %% [markdown]
# # Using K-Means Clustering

# %%
# Finding the within cluster sum of squares- WCSS
WCSS = []
for i in range(1,11):
    kmeans = KMeans(n_clusters=i, random_state=48)
    kmeans.fit(norm_data)
    WCSS.append(kmeans.inertia_)
WCSS
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
# Deciding the hyper-parameter K
# Use elbow-plot

plt.plot(range(1,11),WCSS)
plt.title('Elbow Method')
plt.xlabel('Number of clusters', )
plt.ylabel('WCSS')
plt.xticks(range(1,11))
plt.show()

# %%
clusters = KMeans(4,random_state= 48)
clusters.fit(norm_data)
clusters.labels_
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([1, 1, 1, ..., 0, 1, 1], dtype=int32)

# %%
# Assign the clusters to the data set
data2['clust'] = clusters.labels_
data2.head()
# Out:
#    Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    28143           0          1          1          1          174
# 1    19244           0          1          1          1          215
# 2    41354           0          1          1          1         4123
# 3    14776           0          1          1          1          500
# 4    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?  \
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1
#
#    clust
# 0      1
# 1      1
# 2      1
# 3      1
# 4      0

# %%
data2.groupby('clust').agg(['mean']).reset_index()
# Out:
#   clust       Balance  Qual_miles cc1_miles cc2_miles cc3_miles   Bonus_miles  \
#                  mean        mean      mean      mean      mean          mean
# 0     0  72378.903670  119.606422  3.077982  1.024771  1.018349  31486.477982
# 1     1  88484.857577  175.062961  1.495441  1.008250  1.001737   8110.131568
# 2     2   5129.247934    8.285124  1.004132  1.004132  1.000000    891.388430
# 3     3  28617.579670  112.000000  3.280220  1.030220  1.068681  42166.565934
#
#   Bonus_trans Flight_miles_12mo Flight_trans_12 Days_since_enroll    Award?
#          mean              mean            mean              mean      mean
# 0   17.476147        445.017431        1.317431       4044.253211  0.477064
# 1    8.770734        476.973079        1.439427       4060.013895  0.255319
# 2    3.012397         66.466942        0.194215       4843.239669  0.185950
# 3   17.634615        659.725275        1.909341       4229.689560  0.901099

# %%
plt.scatter(data2['clust'],data2['Balance'], c=clusters.labels_)

# %%
clusters.inertia_
# Out:
# 116.32481600680401

# %% [markdown]
# # Using H-Cluster Algorithm

# %%
# Ploting a dendrogram using the normalized data
plt.figure(figsize=(15, 5))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Index')
plt.ylabel('Distance')
dendrogram = sch.dendrogram(sch.linkage(norm_data, method='complete',metric='euclidean'))

# %%
data3 = data1.copy()
data3.head()
# Out:
#    Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    28143           0          1          1          1          174
# 1    19244           0          1          1          1          215
# 2    41354           0          1          1          1         4123
# 3    14776           0          1          1          1          500
# 4    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
# creating cluster
h_clust = AgglomerativeClustering(n_clusters=5,affinity='euclidean',linkage='complete')
h_clust.fit(norm_data)
h_clust.labels_
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# array([0, 0, 0, ..., 0, 0, 0])

# %%
# Adding clusters to data set
data3['clust'] = h_clust.labels_
data3
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
# Clustring the data
data3.groupby('clust').agg('mean').reset_index()
# Out:
#    clust       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# 0      0  85958.186325  163.835386   1.876215   1.012638   1.002916
# 1      1  49938.428291  109.797642   3.418468   1.031434   1.049116
# 2      2  15395.744526   93.620438   3.189781   1.021898   1.109489
# 3      3   7222.208122   10.177665   1.005076   1.000000   1.000000
# 4      4   1629.914286    0.000000   1.014286   1.000000   1.000000
#
#     Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# 0  13503.547959    11.000648         469.272197         1.402787
# 1  40242.673870    18.194499         584.611002         1.722986
# 2  44896.007299    17.065693         560.094891         1.708029
# 3   1067.822335     3.395939          72.786802         0.213198
# 4    652.228571     2.571429          42.142857         0.157143
#
#    Days_since_enroll    Award?
# 0        4043.470836  0.301685
# 1        4072.086444  0.717092
# 2        4517.262774  1.000000
# 3        4885.304569  0.182741
# ...

# %%
# Ploting the clusters
plt.scatter(data3['clust'],data3['Balance'], c=h_clust.labels_)

# %% [markdown]
# # Using DBSCAN Clustering

# %%
# Creating a copy of actual data
data4 = data1.copy()
data4
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
# Applying the DBSCAN algorithm
dbscan = DBSCAN(eps=.08, min_samples=4)
dbscan.fit(norm_data)
# Out:
# DBSCAN(eps=0.08, min_samples=4)

# %%
# Clusters
dbscan.labels_
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
# Adding clusters as a column to data set
data4['clust'] = dbscan.labels_

# %%
# Creatng clusters with the data
data4.groupby('clust').agg('mean').reset_index()
# Out:
#    clust       Balance   Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# 0     -1  11956.548780  1071.414634   1.353659   1.024390   1.000000
# 1      0  75253.705158   125.342058   2.079292   1.014113   1.012574
# 2      1   5617.636364     0.000000   1.181818   1.090909   1.000000
# 3      2   2016.750000     0.000000   1.000000   1.000000   1.000000
# 4      3   3544.400000     0.000000   1.000000   1.000000   1.000000
#
#     Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# 0   9472.024390    12.524390        2444.280488         5.975610
# 1  17376.447524    11.605337         420.434180         1.283295
# 2   5008.636364     7.727273          36.363636         0.090909
# 3    849.500000     4.000000           0.000000         0.000000
# 4   2205.000000     8.400000         100.000000         0.200000
#
#    Days_since_enroll    Award?
# 0        4196.036585  0.585366
# 1        4117.784193  0.365666
# 2        4629.545455  0.454545
# ...

# %%
# Ploting the clusters
plt.scatter(data4['clust'],data4['Balance'],c= dbscan.labels_)
